# %% [markdown]
# # 🧹 Module 3 — Class 1 Homework: Data Cleaning
#
# **Topic:** Cleaning — missing values, duplicates, type conversion
#
# ## 📋 What you have to do
#
# This notebook **already has working code**. Your job:
#
# 1. **Run every cell from top to bottom** — it should run with no errors.
# 2. **Add a comment on EVERY code cell** that explains what the cell does, in your own words.
#    - Use `#` to write comments inside the code cell.
#    - Write at least 1 short sentence per cell. Longer is better.
# 3. **Save your notebook** as `Module<X>_Class<Y>_<YourName>.ipynb` and submit.
#
# **Example of a good commented cell:**
#
# ```python
# # Count how many customers churned vs stayed
# # value_counts() returns the number of rows for each unique value
# df['Churn'].value_counts()
# ```
#
# **Example of a BAD comment (do not do this):**
#
# ```python
# # count
# df['Churn'].value_counts()
# ```
#
# ---

# %%
# === SETUP — run this first ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')

url = 'https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv'
df = pd.read_csv(url)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce').fillna(0)
print('Loaded:', df.shape)
# Out:
# Loaded: (7043, 21)

# %%
# Cell 0 explanation:
# Import pandas, numpy, matplotlib and suppress warnings
# Load the Telco Customer Churn dataset from GitHub and clean the TotalCharges column

# %% [markdown]
# ### Cell 1 — see how many missing values per column

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Cell 1 explanation:
# Check how many missing (null) values exist in each column

# %% [markdown]
# ### Cell 2 — check how many duplicate rows we have

# %%
print('Duplicates:', df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
# Cell 2 explanation:
# Check how many fully duplicate rows exist in the dataset

# %% [markdown]
# ### Cell 3 — make a copy and add a fake missing value to test fillna

# %%
df_test = df.copy()
df_test.loc[0:9, 'tenure'] = np.nan
print('Missing tenure now:', df_test['tenure'].isnull().sum())
# Out:
# Missing tenure now: 10

# %%
# Cell 3 explanation:
# Make a copy of the dataframe and artificially set the first 10 tenure values to missing, to test fillna later

# %% [markdown]
# ### Cell 4 — fill missing tenure with the median

# %%
median_tenure = df_test['tenure'].median()
df_test['tenure'] = df_test['tenure'].fillna(median_tenure)
print('After fillna, missing:', df_test['tenure'].isnull().sum())
print('Median used:', median_tenure)
# Out:
# After fillna, missing: 0
# Median used: 29.0

# %%
# Cell 4 explanation:
# Calculate the median tenure and use it to fill the missing tenure values in the test dataframe

# %% [markdown]
# ### Cell 5 — fill missing TotalCharges with 0

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)
print('TotalCharges missing after fillna:', df['TotalCharges'].isnull().sum())
# Out:
# TotalCharges missing after fillna: 0

# %%
# Cell 5 explanation:
# Fill missing TotalCharges values with 0 in the main dataframe

# %% [markdown]
# ### Cell 6 — drop duplicate rows

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)
print(f'Before: {before}, After: {after}, Dropped: {before - after}')
# Out:
# Before: 7043, After: 7043, Dropped: 0

# %%
# Cell 6 explanation:
# Remove duplicate rows from the dataframe and print how many rows were dropped

# %% [markdown]
# ### Cell 7 — convert SeniorCitizen from 0/1 to 'No'/'Yes'

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].map({0: 'No', 1: 'Yes'})
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %%
# Cell 7 explanation:
# Convert SeniorCitizen values from 0/1 to 'No'/'Yes' for better readability

# %% [markdown]
# ### Cell 8 — strip whitespace from gender column

# %%
df['gender'] = df['gender'].str.strip()
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
# Cell 8 explanation:
# Remove extra whitespace from the gender column values and check the counts

# %% [markdown]
# ---
#
# ## 📤 Submit
#
# Comment every cell. Push to `module-3/class_1/submissions/<YourName>/`.
