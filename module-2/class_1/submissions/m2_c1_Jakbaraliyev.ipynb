# %%
print("hello, Ai/ML")
# Out:
# hello, Ai/ML

# %%
age = 21
gpa = 4.65
name = "Akbarali"
is_student = True
scores = [89, 92, 98, 95, 88]

print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 21 <class 'int'>
# 4.65 <class 'float'>
# Akbarali <class 'str'>
# True <class 'bool'>
# [89, 92, 98, 95, 88] <class 'list'>

# %%
def calculate_average(numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count

test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]

print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "Namangan", "Fergana"]

for index, city in enumerate(cities):
    print(f"Index {index}: {city}")
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namangan
# Index 4: Fergana

# %%
import random

# 10 ta tasodifiy ball yaratish
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)

# O'rtacha ballni hisoblash
avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")

# Natijani tekshirish
if avg >= 60:
    print("Result: PASS")
else:
    print("Result: FAIL")
# Out:
# Scores: [35, 45, 48, 9, 4, 80, 88, 26, 23, 13]
# Class average: 37.1
# Result: FAIL
