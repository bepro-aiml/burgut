# %%
print('Hello AI/ML')
# Out:
# Hello AI/ML

# %%
age = 20
gpa = 4.52
name = 'Robiya'
is_student = True
scores =[95, 82, 79, 99, 88]

print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 20 <class 'int'>
# 4.52 <class 'float'>
# Robiya <class 'str'>
# True <class 'bool'>
# [95, 82, 79, 99, 88] <class 'list'>

# %%
def calculate_average(numbers):
  total = sum(numbers)
  count = len(numbers)
  return total/ count
test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]
print('Average 1:', calculate_average(test1))
print('Average 2:', calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ['Tashkent', 'Bukhara', 'Samarkand', 'Khiva', 'Andijan']
for index, city in enumerate(cities):
  print(f'Index {index}: {city}')
# Out:
# Index 0: Tashkent
# Index 1: Bukhara
# Index 2: Samarkand
# Index 3: Khiva
# Index 4: Andijan

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(10)]
print('Scores:', exam_scores)

avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")

if avg > 60:
  print('Result: PASS')
else:
  print('Result: FAIL')
# Out:
# Scores: [82, 12, 67, 48, 91, 38, 30, 55, 49, 80]
# Class average: 55.2
# Result: FAIL
