# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %%
# --- EXAMPLES ---

# Integers
subscriber_count = 10_000_000
age = 25

# Floats
monthly_bill = 89_500.50
accuracy = 0.95

# Strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

# Booleans
is_active = True
payment_on_time = False

# Lists
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

# Check types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")

# %%
# --- List operations ---

# Access by index (0-based)
print(f"First bill: {monthly_bills[0]}")
print(f"Last bill:  {monthly_bills[-1]}")

# Slicing
print(f"First 3 bills: {monthly_bills[:3]}")

# Length
print(f"Number of bills: {len(monthly_bills)}")

# Append
monthly_bills.append(91000)
print(f"After append: {monthly_bills}")

# %%
# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# TODO: Create an integer variable for the customer's age
customer_age = None

# TODO: Create a float variable for their monthly data usage in GB
data_usage_gb = None

# TODO: Create a string variable for their city
city = None

# TODO: Create a boolean for whether they have a contract (vs prepaid)
has_contract = None

# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = None

# TODO: Print all variables with their types (follow the example pattern above)

# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# Mijozning yoshini butun son sifatida yaratamiz
# Create an integer variable for the customer's age
customer_age = 28

# Mijozning oylik ishlatgan internet trafigini (GB) o'nlik son sifatida yaratamiz
# Create a float variable for their monthly data usage in GB
data_usage_gb = 15.5

# Mijoz yashaydigan shahar nomini matn ko'rinishida yaratamiz
# Create a string variable for their city
city = "Samarkand"

# Mijozda shartnoma bor-yo'qligini mantiqiy (True/False) qiymatda yaratamiz
# Create a boolean for whether they have a contract (vs prepaid)
has_contract = True

# Mijozning oxirgi 6 oylik to'lovlarini ro'yxat ko'rinishida saqlaymiz
# Create a list of their last 6 monthly bills (in soum)
bills = [45000, 52000, 48000, 60000, 55000, 58000]

# --- Print Section ---

# Har bir o'zgaruvchini uning qiymati va ma'lumot turi bilan chop etamiz
# Print all variables with their types following the example pattern

print(f"customer_age:  {customer_age} (type: {type(customer_age).__name__})")
print(f"data_usage_gb: {data_usage_gb} (type: {type(data_usage_gb).__name__})")
print(f"city:          {city} (type: {type(city).__name__})")
print(f"has_contract:  {has_contract} (type: {type(has_contract).__name__})")
print(f"bills:         {bills} (type: {type(bills).__name__})")

# =================================================================
# GENERAL OVERVIEW / UMUMIY XULOSA
# =================================================================

# English: This notebook serves as the foundation for Data Analysis using Python.
# O'zbekcha: Ushbu daftar Python-da Ma'lumotlar tahlili uchun poydevor bo'lib xizmat qiladi.

# --- Key Takeaways / Muhim xulosalar ---

# 1. Data Categorization / Ma'lumotlarni toifalash
# English: Int/Float are for math, Str for text, and Bool for logic (True/False).
# O'zbekcha: Int/Float matematikaga, Str matnga, Bool esa mantiqqa (True/False) tegishli.

# 2. The Power of Lists / Ro'yxatlarning kuchi
# English: Lists store multiple items in one variable, making it easier to manage datasets.
# O'zbekcha: Ro'yxatlar bir nechta elementni bitta o'zgaruvchida saqlaydi va ma'lumotlar bilan ishlashni osonlashtiradi.

# 3. Zero-Based Indexing / Noldan boshlanuvchi indeksatsiya
# English: Remember: Python starts counting from 0. The first item is always list[0].
# O'zbekcha: Esda tuting: Python-da sanash 0 dan boshlanadi. Birinchi element doim list[0] bo'ladi.

# 4. F-Strings / Dinamik formatlash
# English: F-strings are the best way to combine text and variables for clear output.
# O'zbekcha: F-string matn va o'zgaruvchilarni birlashtirib, aniq natija chiqarishning eng yaxshi usuli.

# =================================================================

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"
}

# Access values by key
print(f"Customer: {customer['name']}")
print(f"Region:   {customer['region']}")
print(f"Spend:    {customer['monthly_spend']} soum")

# Add a new key
customer["tenure_months"] = 24
print(f"\nFull record: {customer}")

# %%
# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store
# Include at least 5 keys: name, category, price, quantity_sold, rating

# TODO: Create the product dictionary
product = None

# TODO: Print the product name and price

# TODO: Add a new key "discount" with a value between 0 and 1

# TODO: Print all keys using product.keys()

# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store

# Mahsulot ma'lumotlarini lug'at (dictionary) ko'rinishida yaratamiz
# Create the product dictionary with at least 5 keys
product = {
    "name": "Samsung Galaxy S24",  # Mahsulot nomi / Product name
    "category": "Electronics",      # Toifasi / Category
    "price": 12000000,              # Narxi / Price
    "quantity_sold": 150,           # Sotilgan soni / Quantity sold
    "rating": 4.8                   # Reytingi / Rating
}

# Mahsulot nomi va narxini konsolga chiqaramiz
# Print the product name and price
print(f"Product: {product['name']}")
print(f"Price:   {product['price']} soum")

# Lug'atga yangi "discount" (chegirma) kalitini qo'shamiz
# Add a new key "discount" with a value between 0 and 1
product["discount"] = 0.15  # 15% chegirma / 15% discount

# Lug'atdagi barcha kalitlarni (nomlarni) chop etamiz
# Print all keys using product.keys()
print(f"Product keys: {product.keys()}")

# =================================================================
# GENERAL OVERVIEW: DICTIONARIES / LUG'ATLAR BO'YICHA XULOSA
# =================================================================

# English: A dictionary is a more powerful way to organize data than a list 
# because every value has a descriptive Key. 
# O'zbekcha: Lug'at (Dictionary) ma'lumotlarni tartiblashda ro'yxatdan ko'ra 
# kuchliroq usuldir, chunki har bir qiymat tavsiflovchi Kalitga (Key) ega.

# --- Key Takeaways / Muhim xulosalar ---

# 1. Structure / Tuzilishi
# English: It works like a real-world dictionary: Word = Key, Definition = Value.
# O'zbekcha: Bu xuddi haqiqiy lug'atdek ishlaydi: So'z = Kalit, Ta'rif = Qiymat.

# 2. Database Mapping / Ma'lumotlar bazasiga o'xshashligi
# English: Think of a dictionary as a single row in a table. Keys are columns.
# O'zbekcha: Lug'atni jadvaldagi bitta qator deb tasavvur qiling. Kalitlar — ustun nomlari.

# 3. Accessing Data / Ma'lumotga murojaat
# English: Use brackets [] with the key name to get a specific value.
# O'zbekcha: Ma'lum bir qiymatni olish uchun qavs [] ichida kalit nomidan foydalaning.

# 4. Flexibility / Moslashuvchanlik
# English: You can easily add new information by assigning a value to a new key.
# O'zbekcha: Yangi kalitga qiymat biriktirish orqali osonlikcha yangi ma'lumot qo'shish mumkin.

# =================================================================

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")

# %%
# --- EXAMPLE: function with multiple returns ---

def describe_bills(bills):
    """Return basic statistics for a list of bills."""
    avg = sum(bills) / len(bills)
    minimum = min(bills)
    maximum = max(bills)
    return avg, minimum, maximum

avg, low, high = describe_bills(bills)
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")

# %%
# --- TODO: Write your own functions ---

# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input
#         and returns:
#         - "premium" if spend > 150000
#         - "standard" if spend is between 50000 and 150000 (inclusive)
#         - "basic" if spend < 50000

def classify_customer(monthly_spend):
    # TODO: implement this function
    pass

# Test your function:
# print(classify_customer(200000))  # should print "premium"
# print(classify_customer(75000))   # should print "standard"
# print(classify_customer(30000))   # should print "basic"

# %%
# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:
#         - total_customers (int)
#         - churned_customers (int)
#         Returns the churn rate as a percentage (float).

def calculate_churn_rate(total_customers, churned_customers):
    # TODO: implement this function
    pass

# Test:
# print(calculate_churn_rate(10000, 350))  # should print 3.5

# --- TODO 1: classify_customer ---
# Mijozlarni xarajatiga qarab toifalarga ajratuvchi funksiya
# Write a function that returns a customer category based on monthly spend

def classify_customer(monthly_spend):
    """
    Mijozning oylik xarajatiga qarab turini aniqlaydi.
    Determines customer type based on monthly spend.
    """
    if monthly_spend > 150000:
        return "premium"  # Xarajat 150k dan ko'p / Spend > 150k
    elif 50000 <= monthly_spend <= 150000:
        return "standard" # Xarajat 50k va 150k oralig'ida / Spend between 50k and 150k
    else:
        return "basic"    # Xarajat 50k dan kam / Spend < 50k

# Funksiyani tekshirish (Test)
print(f"Spend 200,000: {classify_customer(200000)}") 
print(f"Spend 75,000:  {classify_customer(75000)}")  
print(f"Spend 30,000:  {classify_customer(30000)}")   

# --- TODO 2: calculate_churn_rate ---
# Mijozlarning chiqib ketish koeffitsientini (churn rate) hisoblash funksiyasi
# Write a function that calculates churn rate as a percentage

def calculate_churn_rate(total_customers, churned_customers):
    """
    Chiqib ketgan mijozlar foizini hisoblaydi.
    Calculates the percentage of churned customers.
    """
    # Foizni hisoblash: (chiqqanlar / jami) * 100
    # Formula: (churned / total) * 100
    rate = (churned_customers / total_customers) * 100
    return rate

# Funksiyani tekshirish (Test)
# 10,000 mijozdan 350 tasi ketsa, natija 3.5 chiqishi kerak
churn_result = calculate_churn_rate(10000, 350)
print(f"Churn Rate: {churn_result}%")

# =================================================================
# GENERAL OVERVIEW: FUNCTIONS / FUNKSIYALAR HAQIDA XULOSA
# =================================================================

# English: Functions are reusable "machines". You give them inputs (arguments), 
# they process data, and they return an output.
# O'zbekcha: Funksiyalar — bu qayta ishlatiladigan "mashinalar". Siz unga 
# ma'lumot (argument) berasiz, u qayta ishlaydi va natija qaytaradi.

# --- Key Takeaways / Muhim xulosalar ---

# 1. Modularity / Modullik
# English: Instead of writing the same logic 100 times, write it once in a function.
# O'zbekcha: Bir xil mantiqni 100 marta yozish o'rniga, uni bir marta funksiyaga yozing.

# 2. Input & Output / Kirish va Chiqish
# English: 'Arguments' are what goes in, 'Return' is what comes out.
# O'zbekcha: 'Arguments' — bu kiruvchi ma'lumot, 'Return' — bu natija.

# 3. Docstrings / Hujjatlashtirish
# English: Always use """Text""" to explain what your function does.
# O'zbekcha: Funksiya nima qilishini tushuntirish uchun doim """Matn""" (docstring)dan foydalaning.

# 4. Clean Code / Toza kod
# English: Functions make your main code much shorter and easier to read.
# O'zbekcha: Funksiyalar asosiy kodingizni qisqaroq va o'qishga osonroq qiladi.

# =================================================================

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# --- EXAMPLE: basic for loop ---

regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]

for region in regions:
    print(f"Processing data for: {region}")

# %%
# --- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")

# %%
# --- EXAMPLE: loop with conditional ---

customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")

# %%
# --- TODO: Loop exercises ---

# TODO 1: Using the `customers` list above, loop through and classify each customer
#         using your classify_customer function from Section 3.
#         Print: "Name: <name>, Tier: <tier>"

# Your code here:

# %%
# TODO 2: Given the list of scores below, use enumerate to print each score
#         with its rank (starting from 1), and mark scores above 90 with " -- HIGH"
#
# Expected output:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   ...

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Your code here:

# %%
# TODO 3: Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

# Your code here:


# --- TODO 1: classify_customer loop ---
# Customers ro'yxatidagi har bir mijozni funksiya yordamida klassifikatsiya qilish
# Loop through customers and classify them using the function from Section 3

print("Customer Classification:")
for c in customers:
    # Avvalgi bo'limda yaratgan funksiyamizni chaqiramiz
    # Call the function we created in the previous section
    tier = classify_customer(c["spend"])
    print(f"Name: {c['name']}, Tier: {tier}")


# --- TODO 2: enumerate scores ---
# Ballarni tartib raqami bilan chiqarish va 90 dan yuqorisini belgilash
# Print scores with their rank (starting from 1) and mark those > 90

print("\nScore Rankings:")
scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

for i, score in enumerate(scores):
    rank = i + 1  # Indeks 0 dan boshlangani uchun 1 qo'shamiz / Add 1 as index starts at 0
    suffix = ""
    
    if score > 90:
        suffix = " -- HIGH"
    
    print(f"Rank {rank}: {score}{suffix}")


# --- TODO 3: Manual total and average ---
# sum() va len() ishlatmasdan jami va o'rtachani hisoblash
# Compute total and average manually using a loop

total_sum = 0
count = 0

for s in scores:
    total_sum += s  # Har bir ballni qo'shib boramiz / Add each score to the total
    count += 1      # Elementlar sonini sanaymiz / Count the number of elements

average = total_sum / count

print(f"\nTotal: {total_sum}, Average: {average}")

# =================================================================
# GENERAL OVERVIEW: LOOPS / TSIKLLAR HAQIDA XULOSA
# =================================================================

# English: Loops allow you to automate repetitive tasks by iterating through 
# collections like lists and dictionaries.
# O'zbekcha: Tsikllar ro'yxat va lug'atlar ichidagi ma'lumotlarni birma-bir 
# aylanib chiqish orqali takrorlanuvchi ishlarni avtomatlashtirish imkonini beradi.

# --- Key Takeaways / Muhim xulosalar ---

# 1. Efficiency / Samaradorlik
# English: Instead of writing 1,000 lines of code for 1,000 customers, 
# you write 2 lines of code inside a loop.
# O'zbekcha: 1000 ta mijoz uchun 1000 qator kod yozish o'rniga, 
# tsikl ichida 2 qator kod yozish kifoya.

# 2. Enumerate / Tartiblash
# English: Use 'enumerate' when you need both the index (position) and the value.
# O'zbekcha: Ham tartib raqami (indeks), ham qiymat kerak bo'lganda 'enumerate'dan foydalaning.

# 3. Combining Logic / Mantiqni birlashtirish
# English: Loops are most powerful when combined with 'if' statements 
# and 'functions' to filter and process data.
# O'zbekcha: Tsikllar 'if' shartlari va 'funksiyalar' bilan birga ishlatilganda, 
# ma'lumotlarni saralash va qayta ishlashda juda kuchli vositaga aylanadi.

# 4. Manual Accumulation / Qo'lda hisoblash
# English: Loops help you manually aggregate data (summing, counting) 
# when built-in functions aren't enough.
# O'zbekcha: Tayyor funksiyalar yetarli bo'lmaganda, tsikllar ma'lumotlarni 
# qo'lda yig'ishga (yig'indi, sanoq) yordam beradi.

# =================================================================

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Your code here:
# --- TODO: Final exercise ---

# Toifalarni sanash uchun o'zgaruvchilar (counter) yaratamiz
# Initialize counters for each tier
premium_count = 0
standard_count = 0
basic_count = 0

# 1. Har bir mijoz bo'ylab tsikl (loop) yuritamiz
# Loop through each customer in the dataset
for customer in customers_data:
    spend = customer["monthly_spend"]
    
    # 2. Mijozni klassifikatsiya qilamiz (Section 3 dagi mantiq asosida)
    # Classify customer into tiers based on spend logic
    if spend > 150000:
        tier = "premium"
        # 3. Sanoqni oshiramiz / Increment the count
        premium_count += 1
    elif 50000 <= spend <= 150000:
        tier = "standard"
        standard_count += 1
    else:
        tier = "basic"
        basic_count += 1
    
    # Har bir mijoz uchun natijani chiqaramiz (ixtiyoriy)
    # print(f"Customer {customer['name']}: {tier}")

# 4. Yakuniy hisobotni chop etamiz
# Print the final summary report
print("--- Customer Tier Summary ---")
print(f"Premium:  {premium_count}")
print(f"Standard: {standard_count}")
print(f"Basic:    {basic_count}")

# =================================================================
# FINAL SUMMARY: THE DATA PIPELINE / YAKUNIY XULOSA
# =================================================================

# English: We combined everything: 
# 1. Data (Lists/Dicts) -> 2. Logic (If/Else) -> 3. Automation (Loops) -> 4. Result (Print).
# O'zbekcha: Biz hamma narsani birlashtirdik:
# 1. Ma'lumot (Lists/Dicts) -> 2. Mantiq (If/Else) -> 3. Avtomatlashtirish (Loops) -> 4. Natija.

# --- Key Takeaways / Muhim xulosalar ---

# 1. Aggregation / Ma'lumotlarni yig'ish
# English: Using counters (count += 1) inside a loop is the fundamental 
# way to summarize large datasets.
# O'zbekcha: Tsikl ichida hisoblagichlardan (count += 1) foydalanish — bu 
# katta ma'lumotlarni umumlashtirishning asosiy usuli hisoblanadi.

# 2. Integration / Integratsiya
# English: Real data science tasks always involve nesting different concepts 
# (e.g., accessing a dictionary inside a list during a loop).
# O'zbekcha: Haqiqiy ma'lumotlar bilan ishlash vazifalari doimo turli 
# tushunchalarni birlashtirishni talab qiladi (masalan, tsikl vaqtida ro'yxat 
# ichidagi lug'atga murojaat qilish).

# 3. Scalability / Kattalashtirish imkoniyati
# English: This same code can process 8 customers or 8 million customers. 
# Only the dataset size changes, not the logic.
# O'zbekcha: Ushbu kod 8 ta mijozni ham, 8 millionta mijozni ham birdek 
# qayta ishlay oladi. Faqat ma'lumot hajmi o'zgaradi, mantiq esa o'sha-o'sha.

# =================================================================
