# %%
print("Hello, AI/ML!")
# Out:
# Hello, AI/ML!

# %%
age = 19
gpa = 4.25
name = "Fuzaylbek"
is_student = True
scores = [90, 91, 93, 96, 99]

print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 19 <class 'int'>
# 4.25 <class 'float'>
# Fuzaylbek <class 'str'>
# True <class 'bool'>
# [90, 91, 93, 96, 99] <class 'list'>

# %%
def calc_average(numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count

user_input = input("Enter numbers separated by space: ").split()
numbers = list(map(float, user_input))

print("Average:", calc_average(numbers))
# Out:
# Enter numbers separated by space: 12 121 23 421
# Average: 144.25

# %%
students = ["Aziz", "Jafar", "Gulhayo", "Sarvar", "Sevinch"]
for index, student in enumerate(students):
  print(f"Index {index}: {student}")
# Out:
# Index 0: Aziz
# Index 1: Jafar
# Index 2: Gulhayo
# Index 3: Sarvar
# Index 4: Sevinch

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores: ", exam_scores)

avg = calc_avarage(exam_scores)
print(f"Class avarage: {avg: .1f}")

if avg>= 60:
  print("Result: PASS")
else:
  print("Result: FAIL")
#
# Out:
# Scores:  [92, 33, 28, 85, 27, 63, 77, 10, 21, 98]
# Class avarage:  53.4
# Result: FAIL
